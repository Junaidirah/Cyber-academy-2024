# %% [markdown]
# # Linear Regresion

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Isilah kodingan yang kosong dengan menggunakan tols apa saja yang dapat kalian temukan

# %%
# 1. Load Dataset

# %%
_____ = pd._____('iris.csv')

# %%
# Tampilkan 5 baris pertama dari dataset iris.csv
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
_____.____()

# %%
# tampilkan shape dari dataset untuk melihat jumlah baris dan kolom
# Out:
# (150, 5)

# %%
____.___ # isi kode berikut

# %%
# tampilkan info dari dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
___.info()

# %%
## tampilkan statistik deskriptif dari dataset
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(data.____())

# %%
# import matplotlib.pyplot sebagai plt
# import visualization library seaborn sebagai sns

# %%
import ______________ as ___
import _________ as ___

# %%
# plot figure dari 2 kolom

# %%
____.figure(_______=(12, 6))

# %%
# Sepal Length Distribution
# tambahkan kode untuk membuat distribusi sepal length
# Out:
# Text(0, 0.5, 'Frekuensi')

# %%
plt.____(1, _, _)
sns._____(data['sepal_length'], kde=True, color='____')
plt.____('Distribusi Sepal Length')
plt.____('Sepal Length')
___._____('Frekuensi')

# %%
# Petal Length Distribution
# tampilkan distribusi petal length
# Out:
# Text(0, 0.5, 'Frekuensi')

# %%
plt.___(1, 2, 2)
sns.histplot(data['petal_length'], kde=True, color='green')
__.title('___')
__.xlabel('________')
__.ylabel('_________')

# %%
# tampilkan heat map korelasi antar fitur numerik dari dataset

# %%
# Pastikan hanya kolom numerik yang digunakan untuk korelasi
______ = data.select_dtypes(include=['float64', 'int64'])

# Buat matriks korelasi
__________ = numeric_data.corr()

# Visualisasi heatmap korelasi
plt.figure(figsize=(8, 6))
sns._____(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.____('Heatmap Korelasi Antar Fitur Numerik')
___.___() # untuk menampilkan plot

# %%
# tampilkan korelasi antar fitur numerik
# Out:
# c:\Users\junai\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\junai\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\junai\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\junai\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# ...

# %%
sns.______(data, diag_kind='kde', palette='husl')
plt.show()

# %%
# tampilkan box plot untuk setiap fitur numerik dari dataset agar dapat dilihat secara visual

# %%
plt.figure(figsize=(12, 6))
____ i, column in enumerate(data.select_dtypes(include=['float64', 'int64']).columns, 1): # perut ke kolom numerik
    plt.subplot(1, len(data.select_dtypes(include=['float64', 'int64']).columns), i)
    sns._____(y=data[column], color='____') # untuk menampilkan box plot
    plt.____(f'Box Plot: {column}')
    plt.ylabel(column)

plt.____() # agar tidak saling tumpang tindih
plt.show()

# %%
# 2. Define Features (X) and Target (y)
# untuk memilih fitur dan target

# %%
_ = data[['sepal_length', '____', '____']]  # Features
__ = data['petal_length']  # Target

# %%
# 3. Split Data into Train and Test Sets
# untuk membagi data menjadi train dan test set

# %%
X_____, X_____, y_train, y_test = train_test_split(X, y, test_size=___, random_state=____)

# %%
# 4. Create and Train the Linear Regression Model
# Out:
# LinearRegression()

# %%
model = _______()
_____.fit(X_train, y_train)

# %%
# 5. Make Predictions

# %%
y_____ = model.predict(X_test)

# %%
# 6. Evaluate the Model
# Out:
# Model Evaluation:
# Mean Squared Error (MSE): 0.13
# R-squared (R2): 0.96

# %%
___ = mean_squared_error(y_test, y_pred) # untuk menampilkan mse
___  = r2_score(y_test, y_pred) # untuk menampilkan r2

_____("Model Evaluation:")
_____(f"Mean Squared Error (MSE): {mse:.2f}")
_____(f"R-squared (R2): {r2:.2f}")

# %%
# Optional: Example Prediction for New Data
# Out:
# Predicted petal_length for {'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_width': 0.2}: 1.42

# %%
____ = pd.DataFrame({'-----': [5.0], '-----': [3.5], '------': [0.2]})
______ = model.predict(new_data)
____(f"\nPredicted petal_length for {new_data.iloc[0].to_dict()}: {predicted_petal_length[0]:.2f}")
